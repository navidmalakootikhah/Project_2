# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from config import password

import requests
import time
from datetime import datetime

from scipy.stats import linregress

# Import API key
from config import weather_api_key

# %% [markdown]
# ## DataFrames Related to COVID-19

# %%
# Reading csv files for COVID-19(Cases, Hospitalizations, Death) & NYC Boroughs

bronx_covid_data = "data/covid/Bronx-data-GHyLp.csv"
brooklyn_covid_data = "data/covid/Brooklyn-data-Q7Zjo.csv"
manhattan_covid_data = "data/covid/Manhattan-data-rqvAu.csv"
queens_covid_data = "data/covid/Queens-data-HXuvT.csv"
staten_island_covid_data = "data/covid/Staten Island-data-u1Bfw.csv"

bronx_df = pd.read_csv(bronx_covid_data)
brooklyn_df = pd.read_csv(brooklyn_covid_data)
manhattan_df = pd.read_csv(manhattan_covid_data)
queens_df = pd.read_csv(queens_covid_data)
staten_island_df = pd.read_csv(staten_island_covid_data)

bronx_df.dtypes
# Out:
# DATE_OF_INTEREST    object
# Cases                int64
# Hospitalizations     int64
# Deaths               int64
# dtype: object

# %% [markdown]
# # Adding Borough Columns to the datafarmes

# %%
# Adding Borough Columns to the datafarmes
bronx_df['Borough'] = 'BRONX'
brooklyn_df['Borough'] = 'BROOKLYN'
manhattan_df['Borough'] = 'MANHATTAN'
queens_df['Borough'] = 'QUEENS'
staten_island_df['Borough'] = 'STATEN ISLAND'

# Merging all 5 borough DataFrames into one
frames = [bronx_df, brooklyn_df, manhattan_df, queens_df, staten_island_df]
result_covid = pd.concat(frames).reset_index()


covid_final_df=result_covid.drop(columns=['index'])
covid_final_df = covid_final_df.rename(columns={'DATE_OF_INTEREST':'Date'})

covid_final_df.tail()
# Out:
#            Date  Cases  Hospitalizations  Deaths        Borough
# 470  05/29/2020     15                 0       1  STATEN ISLAND
# 471  05/30/2020      9                 0       0  STATEN ISLAND
# 472  05/31/2020      6                 0       1  STATEN ISLAND
# 473  06/01/2020      2                 0       0  STATEN ISLAND
# 474  06/02/2020      0                 0       0  STATEN ISLAND

# %%
covid = covid_final_df["Borough"].unique()
covid
# Out:
# array(['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND'],
#       dtype=object)

# %% [markdown]
# # Getting all lan, lat of the boroughs

# %%
# Setting the base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Using Imperial as Unit for Fahrenheit 
units = "imperial"

# Building partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Setting up lists to hold reponse info
lat = []
lng = []

# Loop through the list of cities and perform a request for data on each
for index, city in enumerate(covid):
            
    # Filling the Lists if the city was found on the URL
    try:
        response = requests.get(query_url + city).json()
        time.sleep(1)
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])

    except:

        pass

# %%
borough_df = pd.DataFrame({'Borough': covid,
                           'Latitude': lat,
                           'Longitude': lng
                          })

# %%
covid_final_df = covid_final_df.merge(borough_df, on= "Borough")
covid_final_df
# Out:
#            Date  Cases  Hospitalizations  Deaths        Borough  Latitude  \
# 0    02/29/2020      0                 4       0          BRONX     40.83
# 1    03/01/2020      1                 1       0          BRONX     40.83
# 2    03/02/2020      0                 9       0          BRONX     40.83
# 3    03/03/2020      1                 7       0          BRONX     40.83
# 4    03/04/2020      0                 6       0          BRONX     40.83
# ..          ...    ...               ...     ...            ...       ...
# 470  05/29/2020     15                 0       1  STATEN ISLAND     40.58
# 471  05/30/2020      9                 0       0  STATEN ISLAND     40.58
# 472  05/31/2020      6                 0       1  STATEN ISLAND     40.58
# 473  06/01/2020      2                 0       0  STATEN ISLAND     40.58
# 474  06/02/2020      0                 0       0  STATEN ISLAND     40.58
#
#      Longitude
# 0       -73.92
# 1       -73.92
# 2       -73.92
# 3       -73.92
# 4       -73.92
# ..         ...
# 470     -74.15
# 471     -74.15
# 472     -74.15
# 473     -74.15
# 474     -74.15
#
# [475 rows x 7 columns]

# %% [markdown]
# # Creating a DataFrame for Total Number of COVIS-19 Cases, Hospitalizations & Death

# %%
# Creating a DataFrame for Total Number of COVIS-19 Cases, Hospitalizations & Death

covid_total_df = pd.DataFrame()

covid_total_df['Date'] = bronx_df['DATE_OF_INTEREST']

covid_total_df['TotalCases']=""
covid_total_df['TotalHospitalizations']=""
covid_total_df['TotalDeaths']=""
covid_total_df
# Out:
#           Date TotalCases TotalHospitalizations TotalDeaths
# 0   02/29/2020
# 1   03/01/2020
# 2   03/02/2020
# 3   03/03/2020
# 4   03/04/2020
# ..         ...        ...                   ...         ...
# 90  05/29/2020
# 91  05/30/2020
# 92  05/31/2020
# 93  06/01/2020
# 94  06/02/2020
#
# [95 rows x 4 columns]

# %%
# Filling the columns

for i in range (len(covid_total_df)):
    covid_total_df.loc[i,'TotalCases'] = bronx_df.iloc[i,1]+brooklyn_df.iloc[i,1]+staten_island_df.iloc[i,1]+manhattan_df.iloc[i,1]+queens_df.iloc[i,1]
    covid_total_df.loc[i,'TotalHospitalizations'] = bronx_df.iloc[i,2]+brooklyn_df.iloc[i,2]+staten_island_df.iloc[i,2]+manhattan_df.iloc[i,2]+queens_df.iloc[i,2]
    covid_total_df.loc[i,'TotalDeaths'] = bronx_df.iloc[i,3]+brooklyn_df.iloc[i,3]+staten_island_df.iloc[i,3]+manhattan_df.iloc[i,3]+queens_df.iloc[i,3]

covid_total_df['TotalCases'] = covid_total_df['TotalCases'].astype('int32')
covid_total_df['TotalHospitalizations'] = covid_total_df['TotalHospitalizations'].astype('int32')
covid_total_df['TotalDeaths'] = covid_total_df['TotalDeaths'].astype('int32')

covid_total_df.head()
# Out:
#          Date  TotalCases  TotalHospitalizations  TotalDeaths
# 0  02/29/2020           1                     12            0
# 1  03/01/2020           1                      4            0
# 2  03/02/2020           0                     22            0
# 3  03/03/2020           2                     19            0
# 4  03/04/2020           5                     21            0

# %%
# Finding the start Date of COVID-19 & Latest Date

start_date = covid_final_df.iloc[0,0]

latest_date = covid_final_df.iloc[-1,0]

print('Start Date: '+start_date+ ' & Latest Date: '+ latest_date)
# Out:
# Start Date: 02/29/2020 & Latest Date: 06/02/2020

# %% [markdown]
# ## DataFrames Related to CRIMES

# %%
# Reading the CSV file for New York City Police Department

nypd = "data/crimes/NYPD.csv"
nypd_data = pd.read_csv(nypd)
nypd_data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (31) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45975594  04/11/2020 01:50:25 AM  04/11/2020 02:27:47 AM   NYPD
# 1    45975654  04/11/2020 12:14:28 AM  04/11/2020 02:17:36 AM   NYPD
# 2    45975989  04/10/2020 06:31:17 PM  04/11/2020 05:48:01 AM   NYPD
# 3    45975997  04/11/2020 12:31:45 AM  04/11/2020 07:57:45 AM   NYPD
# 4    45976007  04/10/2020 11:31:56 PM  04/11/2020 03:27:47 AM   NYPD
#
#                        Agency Name               Complaint Type  \
# 0  New York City Police Department  Non-Emergency Police Matter
# 1  New York City Police Department  Non-Emergency Police Matter
# 2  New York City Police Department          Noise - Residential
# 3  New York City Police Department          Noise - Residential
# 4  New York City Police Department          Noise - Residential
#
#           Descriptor               Location Type  Incident Zip  \
# 0  Social Distancing  Residential Building/House       10025.0
# 1  Social Distancing                         NaN       10451.0
# 2   Banging/Pounding  Residential Building/House       11419.0
# 3   Loud Music/Party  Residential Building/House       11102.0
# 4   Loud Music/Party  Residential Building/House       10458.0
#
#        Incident Address  ... Vehicle Type Taxi Company Borough  \
# 0  222 WEST  104 STREET  ...          NaN                  NaN
# 1  304 EAST  156 STREET  ...          NaN                  NaN
# 2     107-11 129 STREET  ...          NaN                  NaN
# 3       25-57 31 STREET  ...          NaN                  NaN
# 4  340 EAST  184 STREET  ...          NaN                  NaN
#
#   Taxi Pick Up Location Bridge Highway Name Bridge Highway Direction  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                      NaN
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                      NaN
# 4                   NaN                 NaN                      NaN
#
#    Road Ramp Bridge Highway Segment   Latitude  Longitude  \
# 0        NaN                    NaN  40.799478 -73.967504
# 1        NaN                    NaN  40.821747 -73.919234
# 2        NaN                    NaN  40.686233 -73.814735
# 3        NaN                    NaN  40.769635 -73.918557
# 4        NaN                    NaN  40.858098 -73.895670
#
#                                    Location
# 0  (40.799477899696285, -73.96750426182348)
# 1    (40.82174682885639, -73.9192338660681)
# 2   (40.68623317590883, -73.81473500807529)
# 3   (40.76963491074108, -73.91855696912114)
# 4  (40.858098079528844, -73.89567035668057)
#
# [5 rows x 38 columns]

# %%
# Checking the columns for costomization

nypd_data.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
# Selecting the required columns for creating a new dataFrame

nypd_columns = ['Created Date', 'Complaint Type', 'Descriptor', 'Location Type','Incident Address','City','Borough','Latitude', 'Longitude']

nypd_df = nypd_data[nypd_columns].copy()

nypd_df
# Out:
#                   Created Date               Complaint Type  \
# 0       04/11/2020 01:50:25 AM  Non-Emergency Police Matter
# 1       04/11/2020 12:14:28 AM  Non-Emergency Police Matter
# 2       04/10/2020 06:31:17 PM          Noise - Residential
# 3       04/11/2020 12:31:45 AM          Noise - Residential
# 4       04/10/2020 11:31:56 PM          Noise - Residential
# ...                        ...                          ...
# 320192  04/29/2020 02:50:10 PM             Blocked Driveway
# 320193  04/29/2020 02:50:13 PM             Blocked Driveway
# 320194  04/29/2020 02:50:29 PM             Blocked Driveway
# 320195  04/29/2020 02:50:26 PM              Illegal Parking
# 320196  04/29/2020 02:50:41 PM              Noise - Vehicle
#
#                            Descriptor               Location Type  \
# 0                   Social Distancing  Residential Building/House
# 1                   Social Distancing                         NaN
# 2                    Banging/Pounding  Residential Building/House
# 3                    Loud Music/Party  Residential Building/House
# 4                    Loud Music/Party  Residential Building/House
# ...                               ...                         ...
# 320192                 Partial Access             Street/Sidewalk
# 320193                 Partial Access             Street/Sidewalk
# 320194                      No Access             Street/Sidewalk
# 320195  Posted Parking Sign Violation             Street/Sidewalk
# 320196                Car/Truck Music             Street/Sidewalk
#
#             Incident Address                 City    Borough   Latitude  \
# 0       222 WEST  104 STREET             NEW YORK  MANHATTAN  40.799478
# 1       304 EAST  156 STREET                BRONX      BRONX  40.821747
# 2          107-11 129 STREET  SOUTH RICHMOND HILL     QUEENS  40.686233
# 3            25-57 31 STREET              ASTORIA     QUEENS  40.769635
# 4       340 EAST  184 STREET                BRONX      BRONX  40.858098
# ...                      ...                  ...        ...        ...
# 320192   3600 CORLEAR AVENUE                BRONX      BRONX  40.884454
# 320193   3600 CORLEAR AVENUE                BRONX      BRONX  40.884454
# 320194       76-19 91 AVENUE            WOODHAVEN     QUEENS  40.686247
# 320195    220 STEWART AVENUE             BROOKLYN   BROOKLYN  40.713264
# 320196    406 LORIMER STREET             BROOKLYN   BROOKLYN  40.709122
#
#         Longitude
# 0      -73.967504
# 1      -73.919234
# 2      -73.814735
# 3      -73.918557
# 4      -73.895670
# ...           ...
# 320192 -73.903119
# 320193 -73.903119
# 320194 -73.864151
# 320195 -73.927727
# 320196 -73.948547
#
# [320197 rows x 9 columns]

# %%
# Removing Unspecified from Borough Column
nypd_df = nypd_df[nypd_df['Borough'] != "Unspecified"]

# Checking for being sure that Boroughs are Correct
nypd_df['Borough'].unique()
# Out:
# array(['MANHATTAN', 'BRONX', 'QUEENS', 'BROOKLYN', 'STATEN ISLAND'],
#       dtype=object)

# %%
# Sorting the NYPD DataFrame by Dates
nypd_df= nypd_df.sort_values(['Created Date'])

nypd_df
# Out:
#                   Created Date           Complaint Type  \
# 134381  02/01/2020 01:00:00 AM       Noise - Commercial
# 134287  02/01/2020 01:00:16 AM      Noise - Residential
# 143083  02/01/2020 01:00:16 PM  Noise - Street/Sidewalk
# 141734  02/01/2020 01:00:19 PM          Illegal Parking
# 134360  02/01/2020 01:00:48 AM      Noise - Residential
# ...                        ...                      ...
# 319095  06/02/2020 12:57:54 AM          Illegal Parking
# 318261  06/02/2020 12:58:50 AM  Noise - Street/Sidewalk
# 319569  06/02/2020 12:58:57 AM      Noise - Residential
# 318854  06/02/2020 12:59:13 AM  Noise - Street/Sidewalk
# 318107  06/02/2020 12:59:37 AM          Illegal Parking
#
#                            Descriptor               Location Type  \
# 134381               Loud Music/Party            Store/Commercial
# 134287               Banging/Pounding  Residential Building/House
# 143083                   Loud Talking             Street/Sidewalk
# 141734                Blocked Hydrant             Street/Sidewalk
# 134360               Banging/Pounding  Residential Building/House
# ...                               ...                         ...
# 319095                Blocked Hydrant             Street/Sidewalk
# 318261               Loud Music/Party             Street/Sidewalk
# 319569               Loud Music/Party  Residential Building/House
# 318854                   Loud Talking             Street/Sidewalk
# 318107  Posted Parking Sign Violation             Street/Sidewalk
#
#                 Incident Address              City    Borough   Latitude  \
# 134381  110-46 SUTPHIN BOULEVARD           JAMAICA     QUEENS  40.689070
# 134287        200 BENNETT AVENUE          NEW YORK  MANHATTAN  40.856471
# 143083      425 EAST   14 STREET          NEW YORK  MANHATTAN  40.731055
# 141734           1485 HOE AVENUE             BRONX      BRONX  40.832816
# 134360            1768 77 STREET          BROOKLYN   BROOKLYN  40.612740
# ...                          ...               ...        ...        ...
# 319095                 34 AVENUE               NaN     QUEENS  40.751932
# 318261      488 WEST  130 STREET          NEW YORK  MANHATTAN  40.815552
# 319569           95 OLD BROADWAY          NEW YORK  MANHATTAN  40.818146
# 318854           37-37 83 STREET   JACKSON HEIGHTS     QUEENS  40.749505
# 318107           39-23 23 STREET  LONG ISLAND CITY     QUEENS  40.755166
#
#         Longitude
# 134381 -73.795951
# 134287 -73.933865
# 143083 -73.981783
# 141734 -73.889368
# 134360 -73.998055
# ...           ...
# 319095 -73.902156
# 318261 -73.954126
# 319569 -73.955374
# 318854 -73.883310
# 318107 -73.938640
#
# [319735 rows x 9 columns]

# %%
# Removing information of before the Start Date of COVID-19 from NYPD
nypd_df = nypd_df.loc[nypd_df['Created Date'] > start_date]

# Removing NA Rows
nypd_final_df = nypd_df.dropna()

nypd_final_df
# Out:
#                   Created Date               Complaint Type  \
# 22915   02/29/2020 01:00:47 AM              Illegal Parking
# 25956   02/29/2020 01:01:36 PM              Illegal Parking
# 25421   02/29/2020 01:01:56 AM          Noise - Residential
# 26193   02/29/2020 01:02:10 AM           Noise - Commercial
# 24203   02/29/2020 01:02:39 PM          Noise - Residential
# ...                        ...                          ...
# 318972  06/02/2020 12:57:49 AM  Non-Emergency Police Matter
# 318261  06/02/2020 12:58:50 AM      Noise - Street/Sidewalk
# 319569  06/02/2020 12:58:57 AM          Noise - Residential
# 318854  06/02/2020 12:59:13 AM      Noise - Street/Sidewalk
# 318107  06/02/2020 12:59:37 AM              Illegal Parking
#
#                            Descriptor               Location Type  \
# 22915                 Blocked Hydrant             Street/Sidewalk
# 25956               Blocked Bike Lane             Street/Sidewalk
# 25421                Loud Music/Party  Residential Building/House
# 26193                Loud Music/Party         Club/Bar/Restaurant
# 24203                Loud Music/Party  Residential Building/House
# ...                               ...                         ...
# 318972              Social Distancing            Store/Commercial
# 318261               Loud Music/Party             Street/Sidewalk
# 319569               Loud Music/Party  Residential Building/House
# 318854                   Loud Talking             Street/Sidewalk
# 318107  Posted Parking Sign Violation             Street/Sidewalk
#
#                Incident Address              City    Borough   Latitude  \
# 22915     1550 EAST   96 STREET          BROOKLYN   BROOKLYN  40.635450
# 25956              720 BROADWAY          NEW YORK  MANHATTAN  40.729203
# 25421           772 DEAN STREET          BROOKLYN   BROOKLYN  40.679474
# 26193       131 CHRYSTIE STREET          NEW YORK  MANHATTAN  40.719369
# 24203            1973 81 STREET          BROOKLYN   BROOKLYN  40.607898
# ...                         ...               ...        ...        ...
# 318972  45-20 GREENPOINT AVENUE         SUNNYSIDE     QUEENS  40.741936
# 318261     488 WEST  130 STREET          NEW YORK  MANHATTAN  40.815552
# 319569          95 OLD BROADWAY          NEW YORK  MANHATTAN  40.818146
# 318854          37-37 83 STREET   JACKSON HEIGHTS     QUEENS  40.749505
# 318107          39-23 23 STREET  LONG ISLAND CITY     QUEENS  40.755166
#
#         Longitude
# 22915  -73.892913
# 25956  -73.993567
# 25421  -73.964574
# 26193  -73.993218
# 24203  -73.996035
# ...           ...
# 318972 -73.919623
# 318261 -73.954126
# 319569 -73.955374
# 318854 -73.883310
# 318107 -73.938640
#
# [222966 rows x 9 columns]

# %%
# Removing Time from Date Column
nypd_final_df['Created Date']= nypd_final_df['Created Date'].str.split(" ", n=1, expand= True)

# Renaming the column
nypd_final_df= nypd_final_df.rename(columns={'Created Date': 'Date',
                                            'Complaint Type':'ComplaintType',
                                            'Location Type': 'locationType',
                                            'Incident Address': 'incidentAddress'})

nypd_final_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               Date                ComplaintType  \
# 22915   02/29/2020              Illegal Parking
# 25956   02/29/2020              Illegal Parking
# 25421   02/29/2020          Noise - Residential
# 26193   02/29/2020           Noise - Commercial
# 24203   02/29/2020          Noise - Residential
# ...            ...                          ...
# 318972  06/02/2020  Non-Emergency Police Matter
# 318261  06/02/2020      Noise - Street/Sidewalk
# 319569  06/02/2020          Noise - Residential
# 318854  06/02/2020      Noise - Street/Sidewalk
# 318107  06/02/2020              Illegal Parking
#
#                            Descriptor                locationType  \
# 22915                 Blocked Hydrant             Street/Sidewalk
# 25956               Blocked Bike Lane             Street/Sidewalk
# 25421                Loud Music/Party  Residential Building/House
# 26193                Loud Music/Party         Club/Bar/Restaurant
# 24203                Loud Music/Party  Residential Building/House
# ...                               ...                         ...
# 318972              Social Distancing            Store/Commercial
# 318261               Loud Music/Party             Street/Sidewalk
# 319569               Loud Music/Party  Residential Building/House
# 318854                   Loud Talking             Street/Sidewalk
# 318107  Posted Parking Sign Violation             Street/Sidewalk
#
#                 incidentAddress              City    Borough   Latitude  \
# 22915     1550 EAST   96 STREET          BROOKLYN   BROOKLYN  40.635450
# 25956              720 BROADWAY          NEW YORK  MANHATTAN  40.729203
# 25421           772 DEAN STREET          BROOKLYN   BROOKLYN  40.679474
# 26193       131 CHRYSTIE STREET          NEW YORK  MANHATTAN  40.719369
# 24203            1973 81 STREET          BROOKLYN   BROOKLYN  40.607898
# ...                         ...               ...        ...        ...
# 318972  45-20 GREENPOINT AVENUE         SUNNYSIDE     QUEENS  40.741936
# 318261     488 WEST  130 STREET          NEW YORK  MANHATTAN  40.815552
# 319569          95 OLD BROADWAY          NEW YORK  MANHATTAN  40.818146
# 318854          37-37 83 STREET   JACKSON HEIGHTS     QUEENS  40.749505
# 318107          39-23 23 STREET  LONG ISLAND CITY     QUEENS  40.755166
#
#         Longitude
# 22915  -73.892913
# 25956  -73.993567
# 25421  -73.964574
# 26193  -73.993218
# 24203  -73.996035
# ...           ...
# 318972 -73.919623
# 318261 -73.954126
# 319569 -73.955374
# 318854 -73.883310
# 318107 -73.938640
#
# [222966 rows x 9 columns]

# %% [markdown]
# ## Updating Covid_Final_DF with total number of crimes for each Borough and Date

# %%
# Grouping DF by Borough and Date
total= nypd_final_df.groupby(["Borough","Date"])

crimecount = total["ComplaintType"].count()

crimecount = pd.DataFrame(crimecount)
crimecount = crimecount.reset_index()

# Merging Covid and Crimes by Borough and Date
covid_final_df = crimecount.merge(covid_final_df, on =("Borough", "Date"))

# Renaming the columns
covid_final_df = covid_final_df.rename(columns = {"ComplaintType": "TotalCrimes"})

covid_final_df
# Out:
#            Borough        Date  TotalCrimes  Cases  Hospitalizations  Deaths  \
# 0            BRONX  02/29/2020          300      0                 4       0
# 1            BRONX  03/01/2020          343      1                 1       0
# 2            BRONX  03/02/2020          249      0                 9       0
# 3            BRONX  03/03/2020          233      1                 7       0
# 4            BRONX  03/04/2020          243      0                 6       0
# ..             ...         ...          ...    ...               ...     ...
# 470  STATEN ISLAND  05/29/2020           99     15                 0       1
# 471  STATEN ISLAND  05/30/2020          151      9                 0       0
# 472  STATEN ISLAND  05/31/2020          140      6                 0       1
# 473  STATEN ISLAND  06/01/2020           73      2                 0       0
# 474  STATEN ISLAND  06/02/2020            4      0                 0       0
#
#      Latitude  Longitude
# 0       40.83     -73.92
# 1       40.83     -73.92
# 2       40.83     -73.92
# 3       40.83     -73.92
# 4       40.83     -73.92
# ..        ...        ...
# 470     40.58     -74.15
# 471     40.58     -74.15
# 472     40.58     -74.15
# 473     40.58     -74.15
# 474     40.58     -74.15
#
# [475 rows x 8 columns]

# %%
# Creating Total Number of Crimes based on date

crimes_total_df = nypd_final_df.groupby(['Date']).count()
crimes_total_df = crimes_total_df.reset_index()
crimes_total_df
# Out:
#           Date  ComplaintType  Descriptor  locationType  incidentAddress  \
# 0   02/29/2020           1831        1831          1831             1831
# 1   03/01/2020           1845        1845          1845             1845
# 2   03/02/2020           1470        1470          1470             1470
# 3   03/03/2020           1447        1447          1447             1447
# 4   03/04/2020           1405        1405          1405             1405
# ..         ...            ...         ...           ...              ...
# 90  05/29/2020           3510        3510          3510             3510
# 91  05/30/2020           4976        4976          4976             4976
# 92  05/31/2020           4702        4702          4702             4702
# 93  06/01/2020           2258        2258          2258             2258
# 94  06/02/2020            197         197           197              197
#
#     City  Borough  Latitude  Longitude
# 0   1831     1831      1831       1831
# 1   1845     1845      1845       1845
# 2   1470     1470      1470       1470
# 3   1447     1447      1447       1447
# 4   1405     1405      1405       1405
# ..   ...      ...       ...        ...
# 90  3510     3510      3510       3510
# 91  4976     4976      4976       4976
# 92  4702     4702      4702       4702
# 93  2258     2258      2258       2258
# 94   197      197       197        197
#
# [95 rows x 9 columns]

# %% [markdown]
# ## Importing final DataFrames to SQL

# %%
crimes_total_df=crimes_total_df[['Date','ComplaintType']]
crimes_total_df
# Out:
#           Date  ComplaintType
# 0   02/29/2020           1831
# 1   03/01/2020           1845
# 2   03/02/2020           1470
# 3   03/03/2020           1447
# 4   03/04/2020           1405
# ..         ...            ...
# 90  05/29/2020           3510
# 91  05/30/2020           4976
# 92  05/31/2020           4702
# 93  06/01/2020           2258
# 94  06/02/2020            197
#
# [95 rows x 2 columns]

# %%
total_info_map= covid_total_df.merge(crimes_total_df, on='Date')
total_info_map
# Out:
#           Date  TotalCases  TotalHospitalizations  TotalDeaths  ComplaintType
# 0   02/29/2020           1                     12            0           1831
# 1   03/01/2020           1                      4            0           1845
# 2   03/02/2020           0                     22            0           1470
# 3   03/03/2020           2                     19            0           1447
# 4   03/04/2020           5                     21            0           1405
# ..         ...         ...                    ...          ...            ...
# 90  05/29/2020         423                     85           28           3510
# 91  05/30/2020         229                     43           28           4976
# 92  05/31/2020         137                     27            8           4702
# 93  06/01/2020         121                     13            7           2258
# 94  06/02/2020          13                      0            0            197
#
# [95 rows x 5 columns]

# %%
connection_string = f"postgres:{password}@localhost:5432/NYC_COVID19_CRIMES_DB"
engine = create_engine(f'postgresql://{connection_string}')

# Final DF for NYC-COVID-19
covid_final_df.to_sql(name='covid', con=engine, if_exists='replace', index=True)

# Final DF for NYC-CRIMES
nypd_final_df.to_sql(name='crime', con=engine, if_exists='replace', index=True)

# Final DF for total info map
total_info_map.to_sql(name='summary', con=engine, if_exists='replace', index=True)
